# %%
# import sys
# sys.path.insert(0, '../src/models2/')
# import torch
# import torch.nn as nn
# import pandas as pd
# from torch.utils.data import Dataset, DataLoader
# from model_parent import Model_Parent
from src.models2.trainer import train

# %%
epochs = 20
batch_sizes = [16, 32, 64]
learning_rates = [0.0003, 0.0001, 0.001]
league = 'NBA'
bet_type = 'spread'
n_games_list = [3, 5, 10, 15]

# %%
for batch_size in batch_sizes:
    for learning_rate in learning_rates:
        for n_games in n_games_list:
            train(epochs, batch_size, learning_rate, league, bet_type, n_games)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 for learning_rate in learning_rates:
#       3     for n_games in n_games_list:
# ----> 4         train(epochs, batch_size, learning_rate, league, bet_type, n_games)
#
# File ~/Documents/GITHUB/Sports-Betting/src/models2/trainer.py:68, in train(epochs, batch_size, learning_rate, league, bet_type, n_games)
#      65 total = 0
#      67 model.train()
# ---> 68 for i, (inputs, labels) in enumerate(train_dataloader):
#      69     inputs = inputs.to(device)
#      70     labels = labels.to(device)
#
# File ~/anaconda3/envs/bet/lib/python3.8/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# ...
